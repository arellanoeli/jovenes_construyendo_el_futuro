# %%
# Eli Rodríguez Arellano
# Actividad factorial

# %%
num=int(input("Numero: "))
num_factorial=1
if num!=0:
  for i in range(1,num+1):
      num_factorial=num_factorial*i
print("El factorial de {} es: {}".format(num,num_factorial))
# Out:
# Numero: 5
# El factorial de 5 es: 120

# %%
print("Ingrese un numero")
num=int(input())
fact=1
for i in range(1,num+1):
    fact*=i
print("El factorial de ",num, "es: ",fact)
# Out:
# Ingrese un numero
# 6
# El factorial de  6 es:  720

# %%
num=int(input("Numero: "))
num_factorial=1
if num!=0:
  for i in range(1,num+1):
      num_factorial=num_factorial*i
print("El factorial de {} es: {}".format(num,num_factorial))
# Out:
# Numero: 8
# El factorial de 8 es: 40320
