# %%
print("Hola jovenes") #imprime un mensa
print('Bienvenidos') #es una funcion nativa
#esto es un comentario
#un texto puede ir entre "" o ''
#un comentario print ("Hola")
# Out:
# Hola jovenes
# Bienvenidos

# %%
numero=100
type(numero)
# Out:
# int

# %%
decimal=3.1416
type(decimal) #float -> numero decimal
# Out:
# float

# %%
logica=True #verdadero
type(logica) # bool -> booleano -> verdadero o falso
# Out:
# bool

# %%
logica=False #false
type(logica) # bool -> booleano -> verdadero o falso
# Out:
# bool

# %%
num1=10
num=2

# %%
5+11+(12*3)
# Out:
# 52

# %%
print('este programa multiplica dos numeros ')
num1=input('escribe el primero numero: ')
num2=input('escribe el segundo numero: ')
# hace falta codigo
# Out:
# este programa multiplica dos numeros
# escribe el primero numero: 33
# escribe el segundo numero: 3

# %%
type(num1)
# Out:
# str

# %%
print('Este programa mnultiplica dos numeros')
num1=int(input('Escribe el primero numero'))
num2=int(input('Escribe el segundo numero'))
# Out:
# Este programa mnultiplica dos numeros
# Escribe el primero numero22
# Escribe el segundo numero4

# %%
from pdb import Restart
print('esta es una calculadora')
print('Elije el tipo de operacion del menu')
print('1. Sumar')
print('2. Restar')
print('3. Multiplicar')
print('4. Dividir')
res=input('¿que quieres hacer? ')
num1=float(input('Escribe el primero numero'))
num2=float(input('Escribe el segundo numero'))

Esta es una calculadora
Elije el tipo de operacion del menu
1.Sumar
2.Restar
3.Multiplicar
4.Dividir
#Seleccion 'if', 'elif' y 'else'
if 10>5:
print('Verdadero')
else:
print('Falso')
# Out:
#   File "<ipython-input-29-62f4e6c47afe>", line 12
#     Esta es una calculadora
#           ^
# SyntaxError: invalid syntax

# %%
var='Miguel'
if var=='Daniel':
  print('Eres Daniel')
elif var=='Miguel':
 print('Eres Miguel')
else:
  print('No eres Daniel ni Miguel')
# Out:
# Eres Miguel

# %%
num1=10
num2=3
if num1==num2:
  print('son iguales')
elif num1>num2:
  print('el primero es mayor')
elif num1<num2:
      print('el segundo es mayor')
      # else es opcional
# Out:
# el primero es mayor

# %%
num1=10
num2=10
if num1>=num2:
  print('El primero es mayor o igual')
# Out:
# El primero es mayor o igual

# %%
num1=9
num2=10
if num1<=num2:
print('El primero es menor o igual')
# Out:
#   File "<ipython-input-38-d0eb0a24d177>", line 4
#     print('El primero es menor o igual')
#         ^
# IndentationError: expected an indented block

# %%
usuario_db= 'Eli'
contraseña_db='qwerty'
usuario_ingresado=input('Nombre de usuario:')
contraseña_ingresada=input('contraseña')
  if usuario_ingresado==usuario_db:
  print('usuario encontrado')
  else:
print('usuario encontrado')
if contraseña_ingresada==contraseña_db:
 print('La contraseña coincide') 
 print('entraste al sistema') 
  else:
   print('La contraseña no coincide')
  else:
  print('usuario no encontrado')
# Out:
#   File "<ipython-input-44-b2c5fe937b8a>", line 6
#     print('usuario encontrado')
#         ^
# IndentationError: expected an indented block
