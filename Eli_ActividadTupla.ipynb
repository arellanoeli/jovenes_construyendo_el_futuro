# %%
meses=('Enero','Fenrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre')

# %%
print(meses)
# Out:
# ('Enero', 'Fenrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre')

# %%
meses[0:9]
# Out:
# ('Enero',
#  'Fenrero',
#  'Marzo',
#  'Abril',
#  'Mayo',
#  'Junio',
#  'Julio',
#  'Agosto',
#  'Septiembre')

# %%
for mes in meses:
  print('estamos en el mes de {}'.format(mes))
# Out:
# estamos en el mes de Enero
# estamos en el mes de Fenrero
# estamos en el mes de Marzo
# estamos en el mes de Abril
# estamos en el mes de Mayo
# estamos en el mes de Junio
# estamos en el mes de Julio
# estamos en el mes de Agosto
# estamos en el mes de Septiembre
# estamos en el mes de Octubre
# estamos en el mes de Noviembre
# estamos en el mes de Diciembre

# %%
lista_meses=list(meses)

# %%
lista_meses
# Out:
# ['Enero',
#  'Fenrero',
#  'Marzo',
#  'Abril',
#  'Mayo',
#  'Junio',
#  'Julio',
#  'Agosto',
#  'Septiembre',
#  'Octubre',
#  'Noviembre',
#  'Diciembre']

# %%
calendario={i:'mes' for i in lista_meses}
print(calendario)
# Out:
# {'Enero': 'mes', 'Fenrero': 'mes', 'Marzo': 'mes', 'Abril': 'mes', 'Mayo': 'mes', 'Junio': 'mes', 'Julio': 'mes', 'Agosto': 'mes', 'Septiembre': 'mes', 'Octubre': 'mes', 'Noviembre': 'mes', 'Diciembre': 'mes'}
